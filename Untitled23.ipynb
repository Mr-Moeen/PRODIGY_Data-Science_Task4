# %% [markdown]
# <a href="https://colab.research.google.com/github/Mr-Moeen/PRODIGY_Data-Science_Task4/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Tools & Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('/content/twitter_training.csv')
df.head()
# Out:
#    2401  Borderlands  Positive  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#   im getting on borderlands and i will murder you all ,
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
df.shape
# Out:
# (60954, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60954 entries, 0 to 60953
# Data columns (total 4 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   2401                                                   60954 non-null  int64
#  1   Borderlands                                            60954 non-null  object
#  2   Positive                                               60954 non-null  object
#  3   im getting on borderlands and i will murder you all ,  60400 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.9+ MB

# %%
column_name=['tweetID','entity','sentiment','tweet_content']
df.columns=column_name
df
# Out:
#        tweetID               entity   sentiment  \
# 0         2401          Borderlands    Positive
# 1         2401          Borderlands    Positive
# 2         2401          Borderlands    Positive
# 3         2401          Borderlands    Positive
# 4         2401          Borderlands    Positive
# ...        ...                  ...         ...
# 60949     4847  GrandTheftAuto(GTA)  Irrelevant
# 60950     4847  GrandTheftAuto(GTA)  Irrelevant
# 60951     4847  GrandTheftAuto(GTA)  Irrelevant
# 60952     4847  GrandTheftAuto(GTA)  Irrelevant
# 60953     4848  GrandTheftAuto(GTA)  Irrelevant
#
#                                            tweet_content
# 0      I am coming to the borders and I will kill you...
# 1      im getting on borderlands and i will kill you ...
# 2      im coming on borderlands and i will murder you...
# 3      im getting on borderlands 2 and i will murder ...
# 4      im getting into borderlands and i can murder y...
# ...

# %%
df.isna().sum()
# Out:
# tweetID            0
# entity             0
# sentiment          0
# tweet_content    554
# dtype: int64

# %%
df.dropna(inplace=True) # Remove the all null values
df.isna().sum()
# Out:
# tweetID          0
# entity           0
# sentiment        0
# tweet_content    0
# dtype: int64

# %%
#unneeded columns:
df.drop(columns=['tweetID','tweet_content'],inplace=True)
df.head()
# Out:
#         entity sentiment
# 0  Borderlands  Positive
# 1  Borderlands  Positive
# 2  Borderlands  Positive
# 3  Borderlands  Positive
# 4  Borderlands  Positive

# %%
import matplotlib.pyplot as plt

# Assuming entity_content is already defined as df['entity'].value_counts()
entity_content = df['entity'].value_counts()

# Creating a bar chart
plt.figure(figsize=(10, 8))
entity_content.plot(kind='bar', color='skyblue')
plt.title('Distribution of Entities')
plt.xlabel('Entity')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Rotates the labels on the x-axis to prevent overlap
plt.show()

# %%
entity_content=df['entity'].value_counts()

entity_content.plot(kind='pie', autopct='%1.1f%%', figsize=(10, 12))
plt.title('Distribution of entities')
plt.show()

# %%
# Count the occurrences of each sentiment label
sentiment_counts = df['sentiment'].value_counts()
colors = ['skyblue', 'salmon', 'blue', 'red']
# Plot the sentiment distribution
sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values,hue=sentiment_counts.index,palette=colors)
plt.title('Sentiment Distribution for Borderlands')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(16, 6))
sns.countplot(x='entity', data=df, hue='sentiment', edgecolor='black', saturation=0.75)
plt.title('Distribution of Entity by Sentiments')
plt.legend(title='Sentiment')
plt.xticks(rotation=90);
